# %% [markdown]
# # Lecture 01: Expressions

# %% [markdown]
# ---

# %% [markdown]
# ## Overview
#
# * [Python](#Python)
# * [Jupyter Notebooks](#Jupyter-Notebooks)
# * [Expressions](#Expressions)
# * [Names](#Names)
# * [Function Calls](#Function-Calls)
# * [Errors and Exceptions](#Errors-and-Exceptions)

# %% [markdown]
# ---

# %% [markdown]
# ## Python

# %% [markdown]
# ---

# %% [markdown]
# ### Python 3.11

# %% [markdown]
# * Python is popular both for data science & general software development
# * Mastering the language fundamentals is critical
# * Learn through practice, not by reading or listening
# * Follow along with the lecture notebook posted on the Canvas Lecture pages.
#     * You can follow along with your own copy of the notebook to help the lectures feel more interactive and to get more practice with the language.

# %% [markdown]
# ---

# %% [markdown]
# #### Check Version

# %% [markdown]
# See the version of Python installed on this system.

# %%
# !python --version
# Out:
# Python 3.11.14

# %% [markdown]
# ---

# %% [markdown]
# ## Jupyter Notebooks

# %% [markdown]
# ---

# %% [markdown]
# ### What are Notebooks?

# %% [markdown]
# * [Jupyter Notebooks](https://jupyter-notebook.readthedocs.io/) are web applications
# * Some things you can do with notebooks:
#     * develop and run computer-interpreted code
#     * engage with and produce human-focused documentation
#     * support reproducible science
#     * and more!
# * In this class:
#     * Open notebooks from links provided in Canvas (default)
#     * The links are important because they update the notebooks if we make changes

# %% [markdown]
# ---

# %% [markdown]
# ### Jupyter Notebook Interface (Version 7)

# %% [markdown]
# * Notebook Name:
#     * The name displayed at the top of the page, next to the Jupyter logo, reflects the name of the .ipynb file.
#     * Clicking on the notebook name brings up a dialog that allows you to rename it.
# * Menu Bar: The menu bar presents different options that may be used to manipulate the way the notebook functions.
# * Toolbar: The toolbar gives a quick way of performing the most-used operations within the notebook, by clicking on an icon.

# %% [markdown]
# ---

# %% [markdown]
# ### Notebook Cells

# %% [markdown]
# You'll learn a lot about notebooks throughout the quarter, but the main building block of a notebook is called a cell.

# %% [markdown]
# There are two basic types of cells:
# * Code cells
# * Markdown (text) cells

# %% [markdown]
# ---

# %% [markdown]
# #### A Code Cell

# %% [markdown]
# * Code cells interpret computer code.
# * Our notebooks support the Python programming langauge.

# %%
# This is a code cell that prints out the text Hello, CS 8A!

print('Hello, CS 8A!')
print("Hello World!", "\N{EARTH GLOBE ASIA-AUSTRALIA}!")
# Out:
# Hello, CS 8A!
# Hello World! 🌏!

# %% [markdown]
# ---

# %% [markdown]
# #### A Markdown Cell

# %% [markdown]
# * All the formatted text is contained in a Markdown cell.
# * You can double-click these cells to edit them.
# * Markdown is a markup language that allows you to type as if you were using a basic text editor, but you have a few formatting features such as:
#     * **bold**,
#     * *italic*,
#     * etc.
# * There is a straightforward [Markdown guide](https://www.markdownguide.org/basic-syntax/) that shows you how to do all the basic formatting.

# %% [markdown]
# ---

# %% [markdown]
# ### Kernel

# %% [markdown]
# * Computational process that runs the code in the notebook
# * The kernel status appears in the upper right of the notebook:
#     * Open circle: kernel is ready to run a cell
#     * Closed circle: kernel is not ready to run a cell
#     * Circle with a lightning bolt along with the phrase 'No Kernel': kernel has shut down for some reason
# * A number appears to the left of a code cell showing the order in which the code cells have been run
# * If your kernel has shut down:
#     * The "memory" of the notebook has been lost
#     * You will need to re-run the cells
#         * Select `Kernel` -> `Restart` in the Menu Bar
#         * Re-run all the cells you want to run

# %% [markdown]
# ---

# %% [markdown]
# ## Expressions

# %% [markdown]
# ---

# %% [markdown]
# ### What are Expressions?

# %% [markdown]
# Expressions are combinations of symbols that are interpreted to produce some value.

# %% [markdown]
# ---

# %% [markdown]
# ### Demo: Expressions

# %% [markdown]
# Try making a few expressions.

# %%
6 + 8

# %%
1 + 2 * 3 - 4 // 5

# %%
19 % 3

# %%
15 // 2

# %%
3 * 4

# %%
'Data 8'

# %% [markdown]
# ---

# %% [markdown]
# ### Demo: Arithmetic in Python

# %% [markdown]
# ### Operation
# <p>Operator	       Example	Value
# <p>Addition	+	    2 + 3	5
# <p>Subtraction -	2 - 3	-1
# <p>Multiplication	*	2 * 3	6
# <p>Division	/	    7 / 3	2.33333
# <p>Remainder %	    7 % 3	1
# <p>Exponentiation	**	2 ** 0.5	1.41421

# %% [markdown]
# Try performing some basic arithmetic with Python

# %%
# Addition
2 + 3  # addition

# %%
# Multiplication
-2 * 9

# %%
# Division
15 / 2

# %%
# Exponentiation
3 ** 2

# %%
# Modulo
19 % 3

# %%
(2 + 3) * -5

# %%
-(1 + 1) + 2 * (3 * 4 * 5 / 6) ** 3 + 7 + 8 + 9

# %% [markdown]
# ---

# %% [markdown]
# ### Order of Operation

# %% [markdown]
# * Python follows an order of operations when you combine operations in one expression
# * The order for arithmetic is similar to the order from Math class
# * Use parentheses to influence the order
#
# 1. Parentheses (): Expressions inside parentheses are always evaluated first.
# 2. Exponentiation **: Evaluated next; notably, this is right-associative (e.g., 2**3**2 is 2**(3**2)).
# 3. Multiplicative *, /, //, %: Multiplication, division, floor division, and modulus.
# 4. Additive +, -: Addition and subtraction.

# %% [markdown]
# ---

# %% [markdown]
# ### Demo: Order of Operation

# %% [markdown]
# Use parentheses to influence the value for the following expression.

# %%
# The original expression evaluates to 29
2 + 3 * 9
# Out:
# 29

# %%
# Use parentheses to make the expression evaluate to 25
(2 + 3) * 5
# Out:
# 25

# %% [markdown]
# ---

# %% [markdown]
# ![Screenshot 2026-04-08 at 8.30.07 AM.png](attachment:3f744a01-fdbd-401f-bbf2-2baca33a882c.png)

# %%
# Only the last pair of parentheses is necessary.
19 + 6 * 3 - 15 * 100 ** 0.5 * 1 / 30 * 3 / 5 + 4 ** 2 / 2 ** 3 + (6 - 2 / 3) * 12
# Out:
# 100.0

# %% [markdown]
# ## Names

# %% [markdown]
# ---

# %% [markdown]
# ### Assignment Statements

# %% [markdown]
# ### Variables and assignment statements
# A variable is a place to store a value so that it can be referred to later in our code. To define a variable, we use an assignment statement.
# name
#
# x = 23 - 14
#
# An assignment statement changes the meaning of the name to the left of the = symbol.
# The expression on the right-hand side of the = symbol is evaluated before being assigned to the name on the left-hand side.
# e.g. x is bound to 9 (value) not 23 - 14 (expression).

# %% [markdown]
# <img src="./assignment_statements.png" width = 50%>
#
# * Statements perform an action
# * An assignment statement changes the meaning of the name to the left of the = symbol
# * The name is bound to a value (not an equation)

# %% [markdown]
# ---

# %% [markdown]
# ### Demo: Names

# %% [markdown]
# * Define a few names
# * Apply them to create arithmetic operations
# * Differentiate between names and strings.

# %%
a = 46

# %%
a

# %%
b = 1 + 2 * 3 - 4 // 5
b

# %%
quarter = 4
quarter

# %%
purchase_price = 5
state_tax_rate = 0.075
county_tax_rate = 0.02
city_tax_rate = 0
sales_tax_rate = state_tax_rate + county_tax_rate + city_tax_rate
sales_tax = purchase_price * sales_tax_rate
sales_tax

# %%
a = 10
b = 20
a + b

# %%
# Option 2
ca_hourly_minimum_wage = 15.00
hours_per_week = 40
weeks_per_year = 52

# %%
hours_per_year = hours_per_week * weeks_per_year

# %%
hours_per_year

# %%
eleven + 8 #Error

# %%
3 = 2 + 1

# %% [markdown]
# ---

# %% [markdown]
# ### Demo: Why Names?

# %% [markdown]
# * See how helpful choices of names can help you and others navigate your code.
# * Notice that you can get the same numbers from arithmetic, but it can be hard to tell what the code refers to.

# %%
hours_per_week = 40 
weeks_per_year = 52

# %%
hours_per_year = hours_per_week * weeks_per_year
hours_per_year

# %%
# Minimum wage for businesses w/26 or more employees as of 2024
ca_hourly_minimum_wage = 16.00

# %%
weekly_wages = hours_per_week * ca_hourly_minimum_wage
weekly_wages

# %%
yearly_wages = hours_per_year * ca_hourly_minimum_wage
yearly_wages

# %%
40 * 16.00

# %%
40 * 52 * 16.00

# %% [markdown]
# ### Extra practice
# Assume you have run the following three lines of code:
#
# side_length = 5
# <p> area = side_length ** 2
# <p>side_length = side_length + 2
#
# <p>What are the values of side_length and area after execution?
#
# Answer this question without actually running any code. Then, to check your answer, copy-paste the three lines of code from above into a code cell and run the cell. Then display the values of the variables by typing each variable name into a code cell and running that cell to see the value of the variable.

# %% [markdown]
# ---

# %% [markdown]
# ## Function Calls

# %% [markdown]
# ---

# %% [markdown]
# ### Anatomy of a Call Expression

# %% [markdown]
# <img src="./anatomy_of_a_call_expression.png" width = 40%>

# %% [markdown]
# Read: "Call `f` on 27."

# %% [markdown]
# ---

# %% [markdown]
# ### Anatomy of a Call Expression - Multiple Arguments

# %% [markdown]
# <img src="./anatomy_of_a_call_expression_multiple_arguments.png" width = 50%>

# %% [markdown]
# ---

# %% [markdown]
# ### Demo: Functions and Call Expressions

# %% [markdown]
# A few functions are available by default, such as abs and round, but most functions that are built into the Python language are stored in a collection of functions called a module. An import statement is used to provide access to a module, such as math or operator
# * Perform function calls with the built-in absolute value function.
# * Try using built-in functions that accept more than 1 argument.

# %% [markdown]
# ### Import statements
# Python doesn't have everything we need built in.
# <p>In order to gain additional functionality, we import modules through import statements.
# <p>Modules are collections of Python functions and values.
# <p>Call these functions using the syntax module.function(), called "dot notation".
# <p>Example: import math
# Some of the many functions built into the math module are sqrt, pow, and log.

# %%
import math
import operator
math.sqrt(operator.add(4, 5))
# Out:
# 3.0

# %%
abs(-5)

# %%
abs(1 - 3)

# %%
min(14, 15)

# %%
math.sqrt(2)

# %%
math.pow(2, 5)
# Out:
# 32.0

# %%
round(123.456)

# %%
max(9)

# %%
math.pi
# Out:
# 3.141592653589793

# %% [markdown]
# ### Nested evaluation
# We can nest many function calls to evaluate sophisticated expressions.

# %%
min(abs(max(-1, -2, -3, min(4, -2))), max(5, 100))
# Out:
# 1

# %% [markdown]
# ---

# %% [markdown]
# ### Function Documentation

# %% [markdown]
# * Use the `help` function to see information about a function
# * Put the `?` in front of a function's name to pull up more detailed documentation in Jupyter.

# %%
# ?round
# Out:
# Signature: round(number, ndigits=None)
# Docstring:
# Round a number to a given precision in decimal digits.
#
# The return value is an integer if ndigits is omitted or None.  Otherwise
# the return value has the same type as the number.  ndigits may be negative.
# Type:      builtin_function_or_method

# %% [markdown]
# ---

# %% [markdown]
# * Explore the documentation for the `round` function.
# * Notice that you can explicitly specify argument values, but Python can also know what to do based on the position of the values.

# %% [markdown]
# ### Concept Check ✅
# <p>Assume you have run the following statements:
#
# <p>x = 3
# <p>y = -2
# <p>Which of these examples results in an error? For the ones that don't error, try to determine what they evaluate to!
#
# <p>A. abs(x, y)
# <p>B. math.pow(x, abs(y))
# <p>C. round(x, max(abs(y ** 2)))
# <p>D. math.pow(x, math.pow(y, x))
# <p>E. More than one of the above

# %% [markdown]
# ---

# %% [markdown]
# ## Errors and Exceptions

# %% [markdown]
# ---

# %% [markdown]
# ### Embracing Errors

# %% [markdown]
# * Errors happen and that is okay!
# * Python provides error messages to help correct errors
# * The size of the printout of the error does not correlate to the size of the error
# * Try your best to learn the details of these messages to help you debug your errors
# * [Python's documentation](https://docs.python.org/3/library/exceptions.html#bltin-exceptions) contains a discription for all the built-in errors messages.

# %% [markdown]
# ---

# %% [markdown]
# ### Syntax Error

# %% [markdown]
# * Syntax errors are very common
# * The indicate that something is wrong with the format of the code
# * The ^ symbol used to *try* and point out where the error might be

# %%
# A SyntaxError
display([1, 2, 3]
# Out:
#   Cell In[5], line 2
#     display([1, 2, 3]
#                      ^
# SyntaxError: incomplete input

# %% [markdown]
# ---

# %% [markdown]
# ### Name Error

# %% [markdown]
# * This is another common error for this course
# * Name errors indicate the name used has not been defined
# * If the kernel shuts down and cells need to be re-run this error could show up

# %%
# A NameError
print(a_name)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 2
#       1 # A NameError
# ----> 2 print(a_name)
#
# NameError: name 'a_name' is not defined

# %% [markdown]
# ---

# %% [markdown]
# ## Attribution

# %% [markdown]
# This content is licensed under the <a href="https://creativecommons.org/licenses/by-nc-sa/4.0/">Creative Commons Attribution-NonCommercial-ShareAlike 4.0 International License (CC BY-NC-SA 4.0)</a> and derived from the <a href="https://www.data8.org/">Data 8: The Foundations of Data Science</a> offered by the University of California, Berkeley.
#
# <img src="./by-nc-sa.png" width=100px>
